# %% [markdown]
# url 1 : https://sn.coinafrique.com/categorie/vetements-homme
#
#
# V1: type habits, V2 : price, V3 : address , V4 : image_lien
#
# url 2 : https://sn.coinafrique.com/categorie/chaussures-homme
#
#
# V1: type shoes, V2 : price, V3 : address , V4 : image_link
#
# url 3 : https://sn.coinafrique.com/categorie/vetements-enfants
#
#
# V1: type clothes, V2 : price, V3 : address , V4 : image_link
#
# url 4 : https://sn.coinafrique.com/categorie/chaussures-enfants
#
# V1: type shoes, V2 : price, V3 : address , V4 : image_link

# %%
# import the bibliothéque
import pandas as pd
from requests import get
from bs4 import BeautifulSoup as bs

# %%
#for vetements men
url = 'https://sn.coinafrique.com/categorie/vetements-homme'
html_content = get(url)

request = bs(html_content.content,'html.parser')

# %%
#pour les vêtements
def get_info_vetement(containers):
    list = []
    for container in containers:
        link_image = container.find('a','card-image ad__card-image waves-block waves-light').img['src']
        price = container.find('p','ad__card-price').a.text
        adress = container.find('p','ad__card-location').span.text
        type = container.find('p','ad__card-description').a.text
        dic = {
            "type":type,
            "adress":adress,
            "price":price,
            "link_image":link_image
        }
        list.append(dic)
    return list

# %%
#function for getting type vetements
def main_info_vetement(size_page):
    DF = pd.DataFrame()
    for index in range(size_page):
        url = f'https://sn.coinafrique.com/categorie/vetements-homme?page={index}'
        html_content = get(url)
        request = bs(html_content.content,'html.parser')
        containers = request.find_all('div','col s6 m4 l3')
        data_list = get_info_vetement(containers)
        DF = pd.concat([DF,pd.DataFrame(data_list)],axis=0).reset_index(drop=True)
    return DF

# %%
data = main_info_vetement(2)
data
# Out:
#                     type                         adress             price  \
# 0               Emsemble       Colobane, Dakar, Sénégal  Prix sur demande
# 1       Jacket en jeans                  Dakar, Sénégal         12 000CFA
# 2         Ensemble homme       Colobane, Dakar, Sénégal         15 000CFA
# 3              Djalabeh                  Dakar, Sénégal         10 000CFA
# 4              Djalabeh                  Dakar, Sénégal         12 000CFA
# ..                   ...                            ...               ...
# 163     Ensemble blouson    Grand Dakar, Dakar, Sénégal         25 000CFA
# 164   Costumes africains            HLM, Dakar, Sénégal         30 000CFA
# 165  T-shirts Kaddù dund                 Dakar, Sénégal          4 500CFA
# 166             T-shirts                 Dakar, Sénégal          4 500CFA
# 167              Blouson  Dakar Plateau, Dakar, Sénégal          9 000CFA
#
#                                             link_image
# 0    https://images.coinafrique.com/thumb_5636850_u...
# 1    https://images.coinafrique.com/thumb_5657793_u...
# 2    https://images.coinafrique.com/thumb_5640578_u...
# 3    https://images.coinafrique.com/thumb_5657723_u...
# 4    https://images.coinafrique.com/thumb_5657721_u...
# ..                                                 ...
# 163  https://images.coinafrique.com/thumb_5588312_u...
# 164  https://images.coinafrique.com/thumb_5547717_u...
# 165  https://images.coinafrique.com/thumb_5586874_u...
# 166  https://images.coinafrique.com/thumb_5586869_u...
# 167  https://images.coinafrique.com/thumb_5585179_u...
#
# [168 rows x 4 columns]

# %%
#pour les chaussures-hommes
def get_info_chaussures_hommes(containers):
    list = []
    for container in containers:
        link_image = container.find('a','card-image ad__card-image waves-block waves-light').img['src']
        price = container.find('p','ad__card-price').a.text
        adress = container.find('p','ad__card-location').span.text
        type = container.find('p','ad__card-description').a.text
        dic = {
            "type":type,
            "adress":adress,
            "price":price,
            "link_image":link_image
        }
        list.append(dic)
    return list

# %%
#function for getting type chaussures-hommes
def main_info_chaussures_hommes(size_page):
    DF = pd.DataFrame()
    for index in range(size_page):
        url = f'https://sn.coinafrique.com/categorie/chaussures-homme?page={index}'
        html_content = get(url)
        request = bs(html_content.content,'html.parser')
        containers = request.find_all('div','col s6 m4 l3')
        data_list = get_info_chaussures_hommes(containers)
        DF = pd.concat([DF,pd.DataFrame(data_list)],axis=0).reset_index(drop=True)
    return DF

# %%
data = main_info_chaussures_hommes(2)
data
# Out:
#                           type                              adress      price  \
# 0            Chaussures  homme  Parcelle Assainies, Dakar, Sénégal  12 000CFA
# 1                Nice Air Max                       Dakar, Sénégal  25 000CFA
# 2           Nike Air Max moto                       Dakar, Sénégal  25 000CFA
# 3    Baskets Nike Air Max moto                      Dakar, Sénégal  25 000CFA
# 4        Baskets Adidas samba                       Dakar, Sénégal  20 000CFA
# ..                         ...                                 ...        ...
# 163            Baskets Adidas                       Dakar, Sénégal  25 000CFA
# 164          Chaussures homme                       Dakar, Sénégal  20 000CFA
# 165           Mocassins homme                       Dakar, Sénégal  20 000CFA
# 166           Chaussures bouts                      Dakar, Sénégal  25 000CFA
# 167          Chaussures homme                       Dakar, Sénégal  30 000CFA
#
#                                             link_image
# 0    https://images.coinafrique.com/thumb_5658676_u...
# 1    https://images.coinafrique.com/thumb_5658154_u...
# 2    https://images.coinafrique.com/thumb_5658152_u...
# 3    https://images.coinafrique.com/thumb_5658145_u...
# 4    https://images.coinafrique.com/thumb_5656549_u...
# ..                                                 ...
# 163  https://images.coinafrique.com/thumb_5603000_u...
# 164  https://images.coinafrique.com/thumb_5600252_u...
# 165  https://images.coinafrique.com/thumb_5600246_u...
# 166  https://images.coinafrique.com/thumb_5600244_u...
# 167  https://images.coinafrique.com/thumb_5600240_u...
#
# [168 rows x 4 columns]

# %%
#pour les vetements-enfants
def get_info_vetements_enfants(containers):
    list = []
    for container in containers:
        link_image = container.find('a','card-image ad__card-image waves-block waves-light').img['src']
        price = container.find('p','ad__card-price').a.text
        adress = container.find('p','ad__card-location').span.text
        type = container.find('p','ad__card-description').a.text
        dic = {
            "type":type,
            "adress":adress,
            "price":price,
            "link_image":link_image
        }
        list.append(dic)
    return list

# %%
#function for getting type vetements-enfants
def main_info_vetements_enfants(size_page):
    DF = pd.DataFrame()
    for index in range(size_page):
        url = f'https://sn.coinafrique.com/categorie/vetements-enfants?page={index}'
        html_content = get(url)
        request = bs(html_content.content,'html.parser')
        containers = request.find_all('div','col s6 m4 l3')
        data_list = get_info_vetements_enfants(containers)
        DF = pd.concat([DF,pd.DataFrame(data_list)],axis=0).reset_index(drop=True)
    return DF

# %%
data = main_info_vetements_enfants(2)
data
# Out:
#                                           type  \
# 0               Pantalon pour enfants original
# 1                  Emsemble coton pour enfants
# 2                                 Robe brodée
# 3                                     Robe lin
# 4                                         Robe
# ..                                         ...
# 163                                Robe enfant
# 164                                Robe enfant
# 165  Djialap pour enfant de 4ans jusqua 18ans
# 166                            Dialabé enfant
# 167                           Djialabé enfant
#
#                                  adress             price  \
# 0              Colobane, Dakar, Sénégal          8 000CFA
# 1              Colobane, Dakar, Sénégal          7 000CFA
# 2                       Pikine, Sénégal          6 000CFA
# 3                       Pikine, Sénégal          6 000CFA
# 4                       Pikine, Sénégal          7 000CFA
# ..                                  ...               ...
# 163              Ouakam, Dakar, Sénégal  Prix sur demande
# 164              Ouakam, Dakar, Sénégal  Prix sur demande
# 165            Colobane, Dakar, Sénégal          6 500CFA
# 166                Fass, Dakar, Sénégal         10 000CFA
# 167  Parcelle Assainies, Dakar, Sénégal          8 000CFA
#
#                                             link_image
# 0    https://images.coinafrique.com/thumb_5636849_u...
# 1    https://images.coinafrique.com/thumb_5636847_u...
# 2    https://images.coinafrique.com/thumb_5657323_u...
# 3    https://images.coinafrique.com/thumb_5657317_u...
# 4    https://images.coinafrique.com/thumb_5657313_u...
# ..                                                 ...
# 163  https://images.coinafrique.com/thumb_5225585_u...
# 164  https://images.coinafrique.com/thumb_5225584_u...
# 165  https://images.coinafrique.com/thumb_5181431_u...
# 166  https://images.coinafrique.com/thumb_5181204_u...
# 167  https://images.coinafrique.com/thumb_5196620_u...
#
# [168 rows x 4 columns]

# %%
#pour les vetements-enfants
def get_info_chaussures_enfants(containers):
    list = []
    for container in containers:
        link_image = container.find('a','card-image ad__card-image waves-block waves-light').img['src']
        price = container.find('p','ad__card-price').a.text
        adress = container.find('p','ad__card-location').span.text
        type = container.find('p','ad__card-description').a.text
        dic = {
            "type":type,
            "adress":adress,
            "price":price,
            "link_image":link_image
        }
        list.append(dic)
    return list

# %%
#function for getting type vetements-enfants
def main_info_chaussures_enfants(size_page):
    DF = pd.DataFrame()
    for index in range(size_page):
        url = f'https://sn.coinafrique.com/categorie/chaussures-enfants?page={index}'
        html_content = get(url)
        request = bs(html_content.content,'html.parser')
        containers = request.find_all('div','col s6 m4 l3')
        data_list = get_info_chaussures_enfants(containers)
        DF = pd.concat([DF,pd.DataFrame(data_list)],axis=0).reset_index(drop=True)
    return DF

# %%
data = main_info_chaussures_enfants(2)
data
# Out:
#                         type                       adress             price  \
# 0         Chaussures enfants  Ouest Foire, Dakar, Sénégal          5 000CFA
# 1        Chaussures enfants   Grand Dakar, Dakar, Sénégal          5 000CFA
# 2    Baskets Adidas enfants                Dakar, Sénégal         15 000CFA
# 3              Baskets Nike      Colobane, Dakar, Sénégal         14 000CFA
# 4         Chaussures enfants               Dakar, Sénégal         18 000CFA
# ..                       ...                          ...               ...
# 163        Chaussures enfant     Colobane, Dakar, Sénégal  Prix sur demande
# 164   Chaussures pour enfant         Yoff, Dakar, Sénégal          9 000CFA
# 165        Chaussures enfant     Colobane, Dakar, Sénégal  Prix sur demande
# 166       Chaussures enfants     Colobane, Dakar, Sénégal          3 000CFA
# 167       Chaussures enfants     Colobane, Dakar, Sénégal          4 000CFA
#
#                                             link_image
# 0    https://images.coinafrique.com/thumb_5606532_u...
# 1    https://images.coinafrique.com/thumb_5584411_u...
# 2    https://images.coinafrique.com/thumb_5578754_u...
# 3    https://images.coinafrique.com/thumb_5568313_u...
# 4    https://images.coinafrique.com/thumb_5556000_u...
# ..                                                 ...
# 163  https://images.coinafrique.com/thumb_4517970_u...
# 164  https://images.coinafrique.com/thumb_4516156_u...
# 165  https://images.coinafrique.com/thumb_4513355_u...
# 166  https://images.coinafrique.com/thumb_4464312_u...
# 167  https://images.coinafrique.com/thumb_4464284_u...
#
# [168 rows x 4 columns]
